# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'janithukwattage', 'key': '0a48681c3ad89c5e082775eb31f3bf73'}

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: bleach in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (2025.8.3)
# Requirement already satisfied: charset-normalizer in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (3.4.3)
# Requirement already satisfied: idna in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (3.10)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (1.17.0)
# Collecting text-unidecode (from kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: urllib3>=1.15.1 in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /Users/janith_u/Al Learning/Sentiment-Analysis-ML/env/lib/python3.13/site-packages (from kaggle) (0.5.1)
# Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
# Downloading protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl (426 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, protobuf, kaggle
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [kaggle]━━━━ 4/5 [kaggle]
# Successfully installed kaggle-1.7.4.5 protobuf-6.32.1 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.67.1

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
